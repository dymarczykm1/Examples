# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Bringing in prepay information
df = pd.read_csv(r'C:\Users\MADYMA\Desktop\Python Files\payups.csv')

# Setting the date as the index
df.set_index('Date',inplace=True)\

# Setting seaborn style
sns.set(style='darkgrid', palette='deep')

# %%
sns.heatmap(df.corr())
plt.show()

# %%
df.corr()
# Out:
#                  2.5 M225  2.5 M225 CPR 1M  2.5 M225 CPR 3M  2.5 M225 CPR 6M
# 2.5 M225         1.000000         0.580633         0.650216         0.674556
# 2.5 M225 CPR 1M  0.580633         1.000000         0.903269         0.840355
# 2.5 M225 CPR 3M  0.650216         0.903269         1.000000         0.985247
# 2.5 M225 CPR 6M  0.674556         0.840355         0.985247         1.000000

# %%
plt.figure(figsize=(12, 10))
sns.regplot(df['2.5 M225'], df['2.5 M225 CPR 6M']);
# Out:
# C:\Users\MADYMA\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
